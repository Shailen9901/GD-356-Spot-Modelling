# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing the data into arrays
# first column of the data file is phase data
PTO_PhaseHalf = np.loadtxt("GD356PTO.dat", usecols=(0))
PTO_Phase = np.concatenate((PTO_PhaseHalf, PTO_PhaseHalf+1))
# second column of the data file is flux data
PTO_FluxHalf = np.loadtxt("GD356PTO.dat", usecols=(1))
PTO_Flux = np.concatenate((PTO_FluxHalf+1, PTO_FluxHalf+1))
# third column of the data file is flux error
PTO_ErrorHalf = np.loadtxt("GD356PTO.dat", usecols=(2))
PTO_Error = np.concatenate((PTO_ErrorHalf, PTO_ErrorHalf))

# %%
def mean_data(Phase, Flux, Error, bins):

    Phase_split = np.array_split(Phase, bins)
    Flux_split = np.array_split(Flux, bins)
    Error_split = np.array_split(Error, bins)

    meanPhase = [] * bins
    meanFlux = [] * bins
    meanError = [] * bins

    for i in range(bins):

        meanPhase_i = np.mean(Phase_split[i])
        meanFlux_i = np.sum(Flux_split[i] / (Error_split[i]**2))/ np.sum(1/(Error_split[i]**2))

        meanError_i = np.sqrt(1/np.sum(1/(Error_split[i]**2)))

        meanPhase.append(meanPhase_i)
        meanFlux.append(meanFlux_i)
        meanError.append(meanError_i)
        
    return meanPhase, meanFlux, meanError

meanPhase, meanFlux, meanError = mean_data(PTO_Phase, PTO_Flux, PTO_Error, 200)

# %%
import numpy as np
import starry
import exoplanet as xo
import pymc3 as pm
import pymc3_ext as pmx
import matplotlib.pyplot as plt
import theano.tensor as tt

starry.config.lazy = True
starry.config.quiet = True

# %%
flux = meanFlux
flux_err = np.mean(meanError)
t = meanPhase
theta = np.multiply(meanPhase, 360)

# %%
plt.figure(figsize=(12, 5))

plt.title('PTO', fontsize=20)
plt.xlabel("Rotational phase", fontsize=20)
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=1, color='r', linestyle='--');

# %% [markdown]
# # Medium Radius

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=0.12, testval=0.1)
    radius = pm.Uniform("radius", lower=20.0, upper=60.0, testval=30.0)
    lat = pm.Uniform("lat", lower=-90.0, upper=90.0, testval=0.1)
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=0.1)
    inc = pm.Uniform("inc", lower=0.0, upper=90.0, testval=0.1)
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    flux_model = flux_model/tt.mean(flux_model)

    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [inc, lon, lat, radius, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='81' class='' max='81' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [81/81 00:20&lt;00:00 logp = 8.531e+02]
#     </div>
# message: Optimization terminated successfully.
# logp: 509.0511278208916 -> 853.0766958170655

# %%
keys = ["contrast", "radius", "lat", "lon", "inc"]
param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.10213
# radius       42.14680
# lat          58.95882
# lon          51.62596
# inc          29.84741

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.10213, radius=42.14680, lat=58.95882, lon=51.62596)
map.inc = 29.84741
map.show()

# %%
newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

plt.figure(figsize=(12, 5))

plt.title('PTO - PTO Medium Radius Model', fontsize=20)
plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.mean(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
reduced = chi_squared/195
reduced
# Out:
# 0.4068543418558882

# %% [markdown]
# # Large Radius

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=0.12, testval=0.1)
    radius = pm.Uniform("radius", lower=60.0, upper=90.0, testval=80.0)
    lat = pm.Uniform("lat", lower=-90.0, upper=90.0, testval=0.1)
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=0.1)
    inc = pm.Uniform("inc", lower=0.0, upper=90.0, testval=0.1)
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    flux_model = flux_model/tt.mean(flux_model)
    
    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [inc, lon, lat, radius, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='76' class='' max='76' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [76/76 00:18&lt;00:00 logp = 8.526e+02]
#     </div>
# message: Optimization terminated successfully.
# logp: 511.2248185102533 -> 852.5690124582601

# %%
keys = ["contrast", "radius", "lat", "lon", "inc"]

param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.05747
# radius       87.72168
# lat         -59.28193
# lon          51.62840
# inc          56.95332

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.05747, radius=87.72168, lat=-59.28193, lon=51.62840)
map.inc = 56.95332
map.show()

# %%
newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

plt.figure(figsize=(12, 5))

plt.title('PTO - PTO Large Radius Model', fontsize=20)
plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.mean(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
reduced = chi_squared/195
reduced
# Out:
# 0.4062169626636702

# %%
amplitude = (np.amax(newFlux) - np.amin(newFlux)) / 2
amplitude
# Out:
# 0.011792567690129763

# %% [markdown]
# # TESS - Small Radius

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=1.0, testval=0.5)
    radius = 8.15839
    lat = 47.47122
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=0.1)
    inc = 41.11102
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [lon, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='15' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [15/15 00:00&lt;00:00 logp = 7.299e+02]
#     </div>
# message: Optimization terminated successfully.
# logp: -5.497086890957275 -> 729.8631823342729

# %%
keys = ["contrast", "lon"]
param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.99861
# lon          51.71382

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.99861, radius=8.15839, lat=47.47122, lon=51.71382)
map.inc = 41.11102
map.show()

# %%
newFlux = map.flux(theta=theta)

plt.figure(figsize=(12, 5))

plt.title('PTO - TESS Small Radius Model', fontsize=20)
plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.mean(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
reduced = chi_squared/195
reduced
# Out:
# 1.6429596210616462

# %% [markdown]
# # TESS - Medium Radius

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=1.0, testval=0.5)
    radius = 20.52788
    lat = 47.71131
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=0.1)
    inc = 41.76645
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [lon, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='14' class='' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [14/14 00:00&lt;00:00 logp = 8.612e+02]
#     </div>
# message: Optimization terminated successfully.
# logp: -2583.720872769618 -> 861.2468646814326

# %%
keys = ["contrast", "lon"]
param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.22019
# lon          51.56763

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.22019, radius=20.52788, lat=47.71131, lon=51.56763)
map.inc = 41.76645
map.show()

# %%
newFlux = map.flux(theta=theta)

plt.figure(figsize=(12, 5))

plt.title('PTO - TESS Medium Radius Model', fontsize=20)
plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.mean(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
reduced = chi_squared/195
reduced
# Out:
# 0.3965426841446885

# %% [markdown]
# # TESS - Large Radius

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=1.0, testval=0.5)
    radius = 89.64379
    lat = -44.26156
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=0.1)
    inc = 24.04429
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [lon, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='51' class='' max='51' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [51/51 00:00&lt;00:00 logp = 8.616e+02]
#     </div>
# message: Optimization terminated successfully.
# logp: -45152.200863030776 -> 861.6367991209847

# %%
keys = ["contrast", "lon"]
param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.08313
# lon          51.67330

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.08313, radius=89.64379, lat=-44.26156, lon=51.67330)
map.inc = 24.04429
map.show()

# %%
newFlux = map.flux(theta=theta)

plt.figure(figsize=(12, 5))

plt.title('PTO - TESS Large Radius Model', fontsize=20)
plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.mean(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
reduced = chi_squared/195
reduced
# Out:
# 0.3838046792608498

# %%
amplitude = (np.amax(newFlux) - np.amin(newFlux)) / 2
amplitude
# Out:
# 0.011979165578823225

# %% [markdown]
# # LT - Medium Radius

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=1.0, testval=0.5)
    radius = 21.43014
    lat = 48.30740
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=0.1)
    inc = 40.38516
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [lon, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='15' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [15/15 00:00&lt;00:00 logp = 8.604e+02]
#     </div>
# message: Optimization terminated successfully.
# logp: -3703.6195375631364 -> 860.4041387793903

# %%
keys = ["contrast", "lon"]
param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.20038
# lon          51.75902

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.20038, radius=21.43014, lat=48.30740, lon=51.75902)
map.inc = 40.38516
map.show()

# %%
newFlux = map.flux(theta=theta)

plt.figure(figsize=(12, 5))

plt.title('PTO - LT Medium Radius Model', fontsize=20)
plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.mean(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
reduced = chi_squared/195
reduced
# Out:
# 0.40543176587152624

# %% [markdown]
# # LT - Large Radius

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=1.0, testval=0.5)
    radius = 88.96745
    lat = -42.93086
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=0.1)
    inc = 21.40506
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [lon, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='86' class='' max='86' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [86/86 00:01&lt;00:00 logp = 8.605e+02]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: -40705.23417737591 -> 860.5426927521139

# %%
keys = ["contrast", "lon"]
param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.08672
# lon          51.85701

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.08672, radius=88.96745, lat=-42.93086, lon=51.85701)
map.inc = 21.40506
map.show()

# %%
newFlux = map.flux(theta=theta)

plt.figure(figsize=(12, 5))

plt.title('PTO - LT Large Radius Model', fontsize=20)
plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.mean(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
reduced = chi_squared/195
reduced
# Out:
# 0.3964380300344761

# %%
amplitude = (np.amax(newFlux) - np.amin(newFlux)) / 2
amplitude
# Out:
# 0.011284363319046586

# %% [markdown]
# # WHT - Small Radius

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=1.0, testval=0.5)
    radius = 15.39599
    lat = 50.73618
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=0.1)
    inc = 34.22757
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [lon, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12' class='' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12/12 00:00&lt;00:00 logp = 8.400e+02]
#     </div>
# message: Optimization terminated successfully.
# logp: 280.2631008456194 -> 839.9723906909818

# %%
keys = ["contrast", "lon"]
param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.35890
# lon          52.60548

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.35890, radius=15.39599, lat=50.73618, lon=52.60548)
map.inc = 34.22757
map.show()

# %%
newFlux = map.flux(theta=theta)

plt.figure(figsize=(12, 5))

plt.title('PTO - WHT Small Radius Model', fontsize=20)
plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.mean(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
reduced = chi_squared/195
reduced
# Out:
# 0.6213415788916022

# %%
amplitude = (np.amax(newFlux) - np.amin(newFlux)) / 2
amplitude
# Out:
# 0.00893431060081007

# %% [markdown]
# # WHT - Medium Radius

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=1.0, testval=0.5)
    radius = 22.15108
    lat = 52.69509
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=0.1)
    inc = 36.21473
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [lon, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='17' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [17/17 00:00&lt;00:00 logp = 8.393e+02]
#     </div>
# message: Optimization terminated successfully.
# logp: -5516.682669164396 -> 839.2943588747785

# %%
keys = ["contrast", "lon"]
param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.17731
# lon          52.58177

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.17731, radius=22.15108, lat=52.69509, lon=52.58177)
map.inc = 36.21473
map.show()

# %%
newFlux = map.flux(theta=theta)

plt.figure(figsize=(12, 5))

plt.title('PTO - WHT Medium Radius Model', fontsize=20)
plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.mean(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
reduced = chi_squared/195
reduced
# Out:
# 0.6238111419236638

# %% [markdown]
# # WHT - Large Radius

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=1.0, testval=0.5)
    radius = 88.75199
    lat = -30.72870
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=0.1)
    inc = 19.14318
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [lon, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='50' class='' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [50/50 00:00&lt;00:00 logp = 8.386e+02]
#     </div>
# message: Optimization terminated successfully.
# logp: -79425.64035587726 -> 838.5716239973193

# %%
keys = ["contrast", "lon"]
param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.06501
# lon          52.57098

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.06501, radius=88.75199, lat=-30.72870, lon=52.57098)
map.inc = 19.14318
map.show()

# %%
newFlux = map.flux(theta=theta)

plt.figure(figsize=(12, 5))

plt.title('PTO - WHT Large Radius Model', fontsize=20)
plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.mean(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
reduced = chi_squared/195
reduced
# Out:
# 0.622170615043864

# %%
amplitude = (np.amax(newFlux) - np.amin(newFlux)) / 2
amplitude
# Out:
# 0.008940980088401107

# %% [markdown]
# # Brinkworth 2004

# %%
starry.config.lazy = True

with pm.Model() as model:

    # Priors
    contrast = pm.Uniform("contrast", lower=0.0, upper=1.0, testval=0.5)
    radius = 40
    lat = pm.Uniform("lat", lower=-90.0, upper=90.0, testval=30.0)
    lon = pm.Uniform("lon", lower=-180.0, upper=180.0, testval=45.0)
    inc = pm.Uniform("inc", lower=0.0, upper=90.0, testval=1.4)
    
    
    # Instantiate the map and add the spot
    map = starry.Map(ydeg=30)
    map.inc = inc
    map.spot(contrast=contrast, radius=radius, lat=lat, lon=lon)

    # Compute the flux model
    flux_model = map.flux(theta=theta)
    pm.Deterministic("flux_model", flux_model)

    # Save our initial guess
    flux_model_guess = pmx.eval_in_model(flux_model)

    # The likelihood function assuming known Gaussian uncertainty
    pm.Normal("obs", mu=flux_model, sd=flux_err, observed=flux)

# %%
with model:
    map_soln = pmx.optimize(start=model.test_point)
# Out:
# optimizing logp for variables: [inc, lon, lat, contrast]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='51' class='' max='51' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [51/51 00:11&lt;00:00 logp = 8.470e+02]
#     </div>
# message: Optimization terminated successfully.
# logp: -40780.15042739533 -> 847.0133587123784

# %%
keys = ["contrast", "lat", "lon", "inc"]
param = []
print("{0:12s} {1:10s}".format("", "map_soln"))
for key in keys:
    print("{0:10s} {1:10.5f}".format(key, map_soln[key]))
    param.append(map_soln[key])
# Out:
#              map_soln
# contrast      0.31207
# lat          -6.42770
# lon          50.88692
# inc          12.05867

# %%
starry.config.lazy = False

map = starry.Map(ydeg=30)
map.spot(contrast=0.31207, radius=40, lat=-6.42770, lon=50.88692)
map.inc = 12.05867
map.show()

# %%
newFlux = map.flux(theta=theta)

plt.figure(figsize=(12, 5))

plt.plot(meanPhase, newFlux, label='Starry Light Curve')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.errorbar(meanPhase, flux, yerr=flux_err, color='black', marker='.', linestyle='none', markersize=2, elinewidth=0.5)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=np.median(flux), color='r', linestyle='--');

# %%
residuals = (flux - newFlux)/meanError
chi_squared = np.sum(residuals**2)
chi_squared
# Out:
# 99.2300890444231

# %%
amplitude = (np.amax(newFlux) - np.amin(newFlux)) / 2
amplitude
# Out:
# 0.011093347091087502
