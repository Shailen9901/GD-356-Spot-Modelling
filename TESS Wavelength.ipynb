# %%
import numpy as np
import matplotlib.pyplot as plt

# importing the data into arrays
# first column of the data file is wavelength data
wavelength = np.loadtxt("TessBand.csv", usecols=(0), delimiter=',')
# second column of the data file is transmission data
transmission = np.loadtxt("TessBand.csv", usecols=(1), delimiter=',')

# %%
from matplotlib.pyplot import figure

# creating a figure
plt.figure()
figure(figsize=(8, 6), dpi=80)
# plotting the data as black dots with no line connecting them
plt.plot(wavelength, transmission, color='black', marker='.', linestyle='none', markersize=2)
# adding the x and y axis labels
plt.xlabel('Wavelength (nm)')
plt.ylabel('Sensitivity')
plt.show()

plt.figure()
figure(figsize=(8, 6), dpi=80)
# plotting the data as black dots with no line connecting them
plt.plot(wavelength, transmission, color='black', marker='.', linestyle='-', markersize=0)
# adding the x and y axis labels
plt.xlabel('Wavelength (nm)')
plt.ylabel('Sensitivity')
plt.show()

# %%
mean = np.sum(wavelength * transmission) / np.sum(transmission)
mean
# Out:
# 784.6334234298566

# %%
start = np.linspace(300, 580, 100)
start0 = np.zeros(100)
end = np.linspace(1125, 2000, 200)
end0 = np.zeros(200)

# %%
wavelength = np.concatenate((start, wavelength, end))
transmission = np.concatenate((start0, transmission, end0))

# %%
# creating a figure
plt.figure()
figure(figsize=(8, 6), dpi=80)
# plotting the data as black dots with no line connecting them
plt.plot(wavelength, transmission, color='black', marker='.', linestyle='none', markersize=2)
# adding the x and y axis labels
plt.xlabel('Wavelength (nm)')
plt.ylabel('Sensitivity')
plt.show()

plt.figure()
figure(figsize=(8, 6), dpi=80)
# plotting the data as black dots with no line connecting them
plt.plot(wavelength, transmission, color='black', marker='.', linestyle='-', markersize=0)
# adding the x and y axis labels
plt.xlabel('Wavelength (nm)')
plt.ylabel('Sensitivity')
plt.show()

# %%
mean = np.sum(wavelength * transmission) / np.sum(transmission)
mean
# Out:
# 784.6334234298565
