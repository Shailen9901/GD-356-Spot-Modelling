# %%
import numpy as np
import starry
import matplotlib.pyplot as plt


starry.config.lazy = False
starry.config.quiet = True

# %%
meanPhase = np.linspace(0, 2, num=200, endpoint=True)
theta = np.multiply(meanPhase, 360)

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.04618, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

TESS_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.06984, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

LT_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.10118, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

PTO_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.12773, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

WHT_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.05509, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

ZTFr_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.08973, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

ZTFg_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.23164, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

NUV_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.21885, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

NUV3_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.28845, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

NUV2_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.20529, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

NUV1_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.73682, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

FUV_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.49299, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

FUV3_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.85734, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

FUV2_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.99324, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693

FUV1_newFlux = map.flux(theta=theta)/np.mean(map.flux(theta=theta))

# %%
plt.figure(figsize=(12, 5))

plt.title('NUV - 30 Degree Radius Model', fontsize=20)
plt.plot(meanPhase, NUV_newFlux, label='NUV',linestyle='--')
plt.plot(meanPhase, NUV3_newFlux, label='NUV (2550 - 2950)')
plt.plot(meanPhase, NUV2_newFlux, label='NUV (2150 - 2550)')
plt.plot(meanPhase, NUV1_newFlux, label='NUV (1630 - 2150)')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=1, color='r', linestyle='--')
plt.ylim(np.amin(NUV2_newFlux), np.amax(NUV2_newFlux));

# %%
plt.figure(figsize=(12, 5))

plt.title('FUV - 30 Degree Radius Model', fontsize=20)
plt.plot(meanPhase, FUV_newFlux, label='FUV',linestyle='--')
plt.plot(meanPhase, FUV3_newFlux, label='FUV (1520 - 1715)')
plt.plot(meanPhase, FUV2_newFlux, label='FUV (1330 - 1520)')
plt.plot(meanPhase, FUV1_newFlux, label='FUV (1120 - 1330)')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend()
plt.ylabel("Flux", fontsize=20)
plt.xlabel('Rotational Phase')
plt.ylabel('Flux')
plt.axhline(y=1, color='r', linestyle='--')
plt.ylim(np.amin(FUV1_newFlux), np.amax(FUV1_newFlux));

# %%
plt.figure(figsize=(14, 8))

plt.title('30 Degree Radius Model', fontsize=20)
plt.plot(meanPhase, TESS_newFlux, label='TESS', color='k', zorder=10)
plt.plot(meanPhase, PTO_newFlux, label='PTO', color='red')
plt.plot(meanPhase, NUV2_newFlux, label='NUV (2150 - 2550)', color='gray')
plt.plot(meanPhase, FUV2_newFlux, label='FUV (1330 - 1520)', color='goldenrod')
plt.plot(meanPhase, ZTFr_newFlux, label='ZTF-r', color='magenta')
plt.plot(meanPhase, WHT_newFlux, label='WHT', color='purple')
plt.plot(meanPhase, NUV1_newFlux, label='NUV (1630 - 2150)', color='olive')
plt.plot(meanPhase, FUV1_newFlux, label='FUV (1120 - 1330)', color='blue')
plt.plot(meanPhase, LT_newFlux, label='LT', color='orange')
plt.plot(meanPhase, NUV_newFlux, label='NUV', color='brown')
plt.plot(meanPhase, FUV_newFlux, label='FUV', color='darkturquoise')
plt.plot(meanPhase, ZTFg_newFlux, label='ZTF-g', color='green')
plt.plot(meanPhase, NUV3_newFlux, label='NUV (2550 - 2950)', color='pink')
plt.plot(meanPhase, FUV3_newFlux, label='FUV (1520 - 1715)', color='lawngreen')
plt.xlabel("Rotational phase", fontsize=20)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4), ncol=4, fontsize=16)
plt.ylabel("Relative Flux", fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(y=1, color='r', linestyle='--')
plt.ylim(np.amin(FUV1_newFlux), np.amax(FUV1_newFlux))
plt.xlim(0, 2);
