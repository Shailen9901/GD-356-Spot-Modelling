# %%
import numpy as np
import starry
import matplotlib.pyplot as plt

starry.config.lazy = False
starry.config.quiet = True

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.04618, radius=30, lat=43.98307, lon=45)
map.inc = 46.01693
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.04598, radius=35, lat=50.64638, lon=45)
map.inc = 39.35362
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.04154, radius=40, lat=53.34246, lon=45)
map.inc = 36.65754
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.04899, radius=45, lat=60.37420, lon=45)
map.inc = 29.62580
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.05785, radius=50, lat=65.36171, lon=45)
map.inc = 24.63829
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.07073, radius=55, lat=69.52247, lon=45)
map.inc = 20.47753
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.08659, radius=60, lat=72.76113, lon=45)
map.inc = 17.23887
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.09520, radius=65, lat=74.39755, lon=45)
map.inc = 15.60245
map.show()
