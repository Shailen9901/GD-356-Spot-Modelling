# %%
import numpy as np
import starry
import matplotlib.pyplot as plt

starry.config.lazy = False
starry.config.quiet = True

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.22926, radius=25, lat=65.49716, lon=45.33533)
map.inc = 20.07246
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.20019, radius=30, lat=70.13631, lon=45.33522)
map.inc = 19.86373
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.16745, radius=35, lat=71.16164, lon=45.33508)
map.inc = 18.84001
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.13957, radius=40, lat=71.62306, lon=45.33509)
map.inc = 18.37424
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.13214, radius=45, lat=72.95156, lon=45.33518)
map.inc = 17.04891
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.13819, radius=50, lat=72.44738, lon=45.33533)
map.inc = 13.21241
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.15471, radius=55, lat=76.75232, lon=45.33497)
map.inc = 13.24771
map.show()

# %%
map = starry.Map(ydeg=30)
map.spot(contrast=0.18234, radius=60, lat=76.17267, lon=45.33577)
map.inc = 9.25140
map.show()
